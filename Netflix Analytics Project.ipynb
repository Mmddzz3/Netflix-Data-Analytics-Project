# %%
#import
import pandas as pd
#import seaborn
import seaborn as sns

# %%
data = pd.read_csv("Netflix Dataset.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Check for Duplicate data

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# #### Droping Duplicate data

# %%
data.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.drop_duplicates(inplace= True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# #### Check for null values

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# ### Q1 For Breaking Bad, Who is the Director, and what is its ShowID?

# %%
data[data['Title'].isin(['Breaking Bad'])]
# Out:
#      Show_Id Category         Title Director  \
# 1089   s1090  TV Show  Breaking Bad      NaN
#
#                                                    Cast        Country  \
# 1089  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...  United States
#
#         Release_Date Rating   Duration  \
# 1089  August 2, 2013  TV-MA  5 Seasons
#
#                                          Type  \
# 1089  Crime TV Shows, TV Dramas, TV Thrillers
#
#                                             Description
# 1089  A high school chemistry teacher dying of cance...

# %%
data[data['Title'].str.contains('Breaking Bad')]
# Out:
#      Show_Id Category                                              Title  \
# 1089   s1090  TV Show                                       Breaking Bad
# 1945   s1946    Movie                    El Camino: A Breaking Bad Movie
# 6832   s6831    Movie  The Road to El Camino: Behind the Scenes of El...
#
#             Director                                               Cast  \
# 1089             NaN  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...
# 1945  Vince Gilligan                                         Aaron Paul
# 6832             NaN                                                NaN
#
#             Country      Release_Date Rating   Duration  \
# 1089  United States    August 2, 2013  TV-MA  5 Seasons
# 1945  United States  October 11, 2019  TV-MA    123 min
# 6832  United States  October 29, 2019  TV-14     14 min
#
#                                          Type  \
# 1089  Crime TV Shows, TV Dramas, TV Thrillers
# 1945                        Dramas, Thrillers
# ...

# %% [markdown]
# ### Q2 In which year the highest number of TV shows and movies were released?

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Release_date'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Release_date    datetime64[ns]
# dtype: object

# %%
data['Release_date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Release_date, dtype: int64

# %% [markdown]
# #### Displaying using Bar Graph

# %%
data['Release_date'].dt.year.value_counts().plot(kind='bar')

# %% [markdown]
# ### Q3 How many TV shows and movies are in the dataset?

# %%
data.groupby('Category')

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# #### Displaying using Bar Graph

# %%
sns.countplot(data['Category'])

# %%
data['Year'] = data['Release_date'].dt.year

# %%
data.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description Release_date    Year
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0

# %% [markdown]
# ### Q4 Show all the movies that were released in the year 2014.

# %%
(data['Category'] == 'Movie') & (data['Year'] == 2014)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[(data['Category'] == 'Movie') & (data['Year'] == 2014)]
# Out:
#      Show_Id Category                                              Title  \
# 914     s915    Movie             Bill Burr: I'm Sorry You Feel That Way
# 1026   s1027    Movie  BoJack Horseman Christmas Special: Sabrina's C...
# 1309   s1310    Movie         Chelsea Handler: Uganda Be Kidding Me Live
# 1310   s1311    Movie                 Chelsea Peretti: One of the Greats
# 1902   s1903    Movie                                             E-Team
# 2294   s2295    Movie                        From One Second to the Next
# 2386   s2387    Movie                                          Get Santa
# 3057   s3058    Movie          Iron Man & Captain America: Heroes United
# 3966   s3967    Movie            Marvel's Iron Man & Hulk: Heroes United
# 4147   s4148    Movie                                       Mission Blue
# 4153   s4154    Movie                                               Mitt
# 4333   s4334    Movie      My Little Pony Equestria Girls: Rainbow Rocks
# ...

# %%
data.drop(['Year'], axis=1, inplace= True)

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description Release_date
# 0  In a future where the elite inhabit an island ...   2020-08-14
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Release_date'].dt.year == 2014)]
# Out:
#      Show_Id Category                                              Title  \
# 914     s915    Movie             Bill Burr: I'm Sorry You Feel That Way
# 1026   s1027    Movie  BoJack Horseman Christmas Special: Sabrina's C...
# 1309   s1310    Movie         Chelsea Handler: Uganda Be Kidding Me Live
# 1310   s1311    Movie                 Chelsea Peretti: One of the Greats
# 1902   s1903    Movie                                             E-Team
# 2294   s2295    Movie                        From One Second to the Next
# 2386   s2387    Movie                                          Get Santa
# 3057   s3058    Movie          Iron Man & Captain America: Heroes United
# 3966   s3967    Movie            Marvel's Iron Man & Hulk: Heroes United
# 4147   s4148    Movie                                       Mission Blue
# 4153   s4154    Movie                                               Mitt
# 4333   s4334    Movie      My Little Pony Equestria Girls: Rainbow Rocks
# ...

# %% [markdown]
# ### Q5 Show only the Titles of all the TV shows that were released in India.

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country  \
# ...

# %% [markdown]
# ### Q6 Show only the Titles of all the TV shows that were released in Mexico.

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'Mexico')]
# Out:
#      Show_Id Category                           Title              Director  \
# 12       s13  TV Show                            1994  Diego Enrique Osorno
# 800     s801  TV Show              Becoming Champions                   NaN
# 1437   s1438  TV Show                   Club of Crows                   NaN
# 1490   s1491  TV Show                       Control Z                   NaN
# 1534   s1535  TV Show        Crime Diaries: Night Out           Felipe Cano
# 1535   s1536  TV Show    Crime Diaries: The Candidate                   NaN
# 1594   s1595  TV Show                           Dandy                   NaN
# 1613   s1614  TV Show                     Dark Desire                   NaN
# 1742   s1743  TV Show                        Diablero                   NaN
# 1949   s1950  TV Show                        El Chavo                   NaN
# 1955   s1956  TV Show  El Dragón: Return of a Warrior                   NaN
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'Mexico')]['Title']
# Out:
# 12                                1994
# 800                 Becoming Champions
# 1437                     Club of Crows
# 1490                         Control Z
# 1534          Crime Diaries: Night Out
# 1535      Crime Diaries: The Candidate
# 1594                             Dandy
# 1613                       Dark Desire
# 1742                          Diablero
# 1949                          El Chavo
# 1955    El Dragón: Return of a Warrior
# 2894                          I Am Me!
# 2998                      Ingobernable
# 3228                        Juana Inés
# 3501                         La Piloto
# 3505              La Rosa de Guadalupe
# 3572                      Legend Quest
# 3573     Legend Quest: Masters of Myth
# 3691            Lo que la vida me robó
# 3815          Luis Miguel - The Series
# 4134                     Miss Dynamite
# 4173                           Monarca
# 5124                           Rebelde
# 5284                   Rosario Tijeras
# ...

# %% [markdown]
# ### Q7 Show top 10 Directors, who gave the highest number of TV shows and movies to Netflix.

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ### Q8 Show all the records, where "Category is Movie and Type is Comedy" or "Country is  United Kingdom".

# %%
data[(data['Category'] == 'Movie') & (data['Type'] == 'Comedies') | (data['Country'] == 'United Kingdom') ]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q9 In how many movies Ayushmann Khurrana was in the cast.

# %%
data[(data['Cast'] == 'Ayushmann Khurrana')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Release_date]
# Index: []

# %%
data[(data['Cast'].str.contains('Ayushmann Khurrana'))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-6db4a4305988> in <module>
# ----> 1 data[(data['Cast'].str.contains('Sharad Kelkar'))]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
# -> 2790         if com.is_bool_indexer(key):
#    2791             return self._getitem_bool_array(key)
#    2792
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     134             if not lib.is_bool_array(key):
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: cannot mask with array containing NA / NaN values

# %%
data_new = data.dropna()

# %%
data_new
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data_new[(data_new['Cast'].str.contains('Ayushmann Khurrana'))]
# Out:
#      Show_Id Category              Title             Director  \
# 508     s509    Movie          Andhadhun      Sriram Raghavan
# 589     s590    Movie         Article 15        Anubhav Sinha
# 751     s752    Movie  Bareilly Ki Barfi  Ashwiny Iyer Tiwari
# 2660   s2661    Movie         Hawaizaada  Vibhu Virender Puri
#
#                                                    Cast Country  \
# 508   Tabu, Ayushmann Khurrana, Radhika Apte, Anil D...   India
# 589   Ayushmann Khurrana, Nassar, Manoj Pahwa, Kumud...   India
# 751   Ayushmann Khurrana, Kriti Sanon, Rajkummar Rao...   India
# 2660  Ayushmann Khurrana, Mithun Chakraborty, Pallav...   India
#
#            Release_Date Rating Duration  \
# 508   December 16, 2018  TV-14  137 min
# 589   September 6, 2019  TV-MA  125 min
# 751     August 21, 2018  TV-14  110 min
# 2660  November 19, 2020  TV-14  129 min
#
#                                                Type  \
# 508          Comedies, Dramas, International Movies
# ...

# %% [markdown]
# ### Q10 What are the different ratings defined by Netflix?

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Q11 How many movies got rating 'TV-Y7' in India?

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-Y7')]
# Out:
#      Show_Id Category                                              Title  \
# 162     s163    Movie  A Christmas Special: Miraculous: Tales of Lady...
# 167     s168    Movie                                A Fairly Odd Summer
# 244     s245    Movie                                  A truthful Mother
# 285     s286    Movie                               Abominable Christmas
# 433     s434    Movie  Alpha and Omega: The Legend of the Saw Tooth Cave
# ...      ...      ...                                                ...
# 7061   s7060    Movie                              Thor: Tales of Asgard
# 7136   s7135    Movie                      Tom and Jerry: The Magic Ring
# 7235   s7234    Movie                             Trolls Holiday Special
# 7528   s7527    Movie          Welcome to Monster High: The Origin Story
# 7715   s7714    Movie                            Yo-Kai Watch: The Movie
#
#                                           Director  \
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-Y7')].shape
# Out:
# (95, 12)

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-Y7') & (data['Country'] == 'India')]
# Out:
#      Show_Id Category                                      Title  \
# 244     s245    Movie                          A truthful Mother
# 1317   s1318    Movie      Chhota Bheem and the Curse of Damyaan
# 1322   s1323    Movie                Chhota Bheem Kungfu Dhamaka
# 2307   s2308    Movie       Fukrey Boyzzz: Space Mein Fukrapanti
# 3051   s3052    Movie                                      Iqbal
# 3448   s3449    Movie  Krish Trish and Baltiboy: Face Your Fears
# 4089   s4090    Movie                    Mighty Raju Rio Calling
# 5889   s5889    Movie                 Super Bheem Bana Vajraveer
#
#                                                Director  \
# 244                           Ravishankar Venkateswaran
# 1317                                      Rajiv Chilaka
# 1322                         Rajiv Chilaka, Binayak Das
# 2307                                    Avinash Walzade
# 3051                                    Nagesh Kukunoor
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-Y7') & (data['Country'] == 'India')].shape
# Out:
# (8, 12)

# %% [markdown]
# ### Q12 How many shows got R rating after year 2018?

# %%
data[(data['Rating'] == 'R') & (data['Category'] == 'TV Show')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description Release_date
# 4497  A series of incidents in Afghanistan set compl...   2016-12-10
# 6437  Trapped at a stagecoach stop as a storm rages ...   2019-04-25

# %%
data[(data['Rating'] == 'R') & (data['Category'] == 'TV Show') & (data['Release_date'].dt.year > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description Release_date
# 6437  Trapped at a stagecoach stop as a storm rages ...   2019-04-25

# %% [markdown]
# ### Q13

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data[['Minutes', 'Unit']] = data['Duration'].str.split(' ', expand=True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description Release_date    Year  \
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit...   2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data_tvshow = data[data['Category'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description Release_date    Year  \
# 0  In a future where the elite inhabit an island ...   2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm...   2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
data_tvshow.Country.value_counts()
# Out:
# United States                                705
# United Kingdom                               204
# Japan                                        157
# South Korea                                  147
# India                                         71
#                                             ...
# United States, Colombia                        1
# Switzerland                                    1
# Spain, United Kingdom                          1
# United Arab Emirates                           1
# United States, Netherlands, Japan, France      1
# Name: Country, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64
